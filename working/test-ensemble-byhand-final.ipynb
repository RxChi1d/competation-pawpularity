# %% [markdown]
# ## Import

# %%
import os
import gc
import sys
import warnings
import numpy as np
import pandas as pd
from glob import glob

sys.path.append("../input/pythonbox")
from box import Box

# Torch
import torch
import torch.nn as nn
import torchvision.transforms as T
from torchvision.io import read_image
from torch.utils.data import DataLoader, Dataset 
from torchvision.models import efficientnet_v2_l

# Lightning
import pytorch_lightning as pl
from pytorch_lightning import LightningDataModule, LightningModule, seed_everything

# %%
# !pip uninstall timm --yes

sys.path.append("/kaggle/input/timmmaster")
# import timm
from timm import create_model

# print(timm.__version__)

# %% [markdown]
# ## Config

# %%
config = {'exp_name':'exp_010',
          'root': '../input/petfinder-pawpularity-score/',  # Data root
          'seed': 2023,
          'n_splits': 5,
          'image_size': 224,
          'model':{
              'package': 'timm',  # timm or torchvision
              'name': 'swin_large_patch4_window7_224',
              'output_dim': 1,
              'pretrain': False,
          },
          'save_dir': 'exp010',  # 儲存權重與log的資料夾
          'test_loader': {
              'batch_size': 32,
              'shuffle': False,
              'num_workers': os.cpu_count(),
              'pin_memory': False,
              'drop_last': False
          },
}

config = Box(config)

# %%
config2 = {'exp_name':'exp_007',
          'root': '../input/petfinder-pawpularity-score/',  # Data root
          'seed': 2023,
          'n_splits': 5,
          'image_size': 384,
          'model':{
              'package': 'timm',  # timm or torchvision
              'name': 'swin_large_patch4_window12_384',
              'output_dim': 1,
              'pretrain': False,
          },
          'save_dir': 'exp007',  # 儲存權重與log的資料夾
          'test_loader': {
              'batch_size': 32,
              'shuffle': False,
              'num_workers': os.cpu_count(),
              'pin_memory': False,
              'drop_last': False
          },
}

config2 = Box(config2)

# %%
config3 = {'exp_name':'exp_012',
          'root': '../input/petfinder-pawpularity-score/',  # Data root
          'seed': 2023,
          'n_splits': 5,
          'image_size': 256,
          'model':{
              'package': 'timm',  # timm or torchvision
              'name': 'swinv2_large_window12to16_192to256',
              'output_dim': 1,
              'pretrain': False,
          },
          'save_dir': 'exp012',  # 儲存權重與log的資料夾
          'test_loader': {
              'batch_size': 32,
              'shuffle': False,
              'num_workers': os.cpu_count(),
              'pin_memory': False,
              'drop_last': False
          },
}

config3 = Box(config3)

# %%
config4 = {'exp_name':'exp_025',
          'root': '../input/petfinder-pawpularity-score/',  # Data root
          'seed': 2023,
          'n_splits': 5,
          'image_size': 448,
          'model':{
              'package': 'timm',  # timm or torchvision
              'name': 'eva02_base_patch14_448',
              'output_dim': 1,
              'pretrain': False,
          },
          'save_dir': 'exp025',  # 儲存權重與log的資料夾
          'test_loader': {
              'batch_size': 32,
              'shuffle': False,
              'num_workers': os.cpu_count(),
              'pin_memory': False,
              'drop_last': False
          },
}

config4 = Box(config4)

# %%
config5 = {'exp_name':'exp_016',
          'root': '../input/petfinder-pawpularity-score/',  # Data root
          'seed': 2023,
          'n_splits': 5,
          'image_size': 384,
          'model':{
              'package': 'timm',  # timm or torchvision
              'name': 'cait_m36_384',
              'output_dim': 1,
              'pretrain': False,
          },
          'save_dir': 'exp016',  # 儲存權重與log的資料夾
          'test_loader': {
              'batch_size': 32,
              'shuffle': False,
              'num_workers': os.cpu_count(),
              'pin_memory': False,
              'drop_last': False
          },
}

config5 = Box(config5)

# %%
config6 = {'exp_name':'exp_024',
          'root': '../input/petfinder-pawpularity-score/',  # Data root
          'seed': 2023,
          'n_splits': 5,
          'image_size': 336,
          'model':{
              'package': 'timm',  # timm or torchvision
              'name': 'eva_large_patch14_336',
              'output_dim': 1,
              'pretrain': False,
          },
          'save_dir': 'exp024',  # 儲存權重與log的資料夾
          'test_loader': {
              'batch_size': 32,
              'shuffle': False,
              'num_workers': os.cpu_count(),
              'pin_memory': False,
              'drop_last': False
          },
}

config6 = Box(config6)

# %%
config7 = {'exp_name':'exp_018',
          'root': '../input/petfinder-pawpularity-score/',  # Data root
          'seed': 2023,
          'n_splits': 5,
          'image_size': 384,
          'model':{
              'package': 'timm',  # timm or torchvision
              'name': 'convnextv2_large',
              'output_dim': 1,
              'pretrain': False,
          },
          'save_dir': 'exp018',  # 儲存權重與log的資料夾
          'test_loader': {
              'batch_size': 32,
              'shuffle': False,
              'num_workers': os.cpu_count(),
              'pin_memory': False,
              'drop_last': False
          },
}

config7 = Box(config7)

# %%
config8 = {'exp_name':'exp_015',
          'root': '../input/petfinder-pawpularity-score/',  # Data root
          'seed': 2023,
          'n_splits': 5,
          'image_size': 384,
          'model':{
              'package': 'timm',  # timm or torchvision
              'name': 'convnext_large',
              'output_dim': 1,
              'pretrain': False,
          },
          'save_dir': 'exp015',  # 儲存權重與log的資料夾
          'test_loader': {
              'batch_size': 32,
              'shuffle': False,
              'num_workers': os.cpu_count(),
              'pin_memory': False,
              'drop_last': False
          },
}

config8 = Box(config8)

# %% [markdown]
# ## Fix Seed

# %%
seed_everything(config.seed)

# %% [markdown]
# ## Tools

# %%
def RMSE(predict,target):
    return torch.sqrt(nn.MSELoss()(predict.float(), target.float()))

# %% [markdown]
# ## Dataset

# %%
class PetfinderDataset(Dataset):
    """Dataset
    Args:
        df: the dataframe from csv, and the "Id" column needs to be the path of Image
    """
    def __init__(self, df, transform=None, image_size=384):
        
        self._X = df["Id"].values
        self._y = None
        self.transform = transform
        
        # 判斷有沒有分數
        if "Pawpularity" in df.keys():
            self._y = df["Pawpularity"].values
            
    def __len__(self):
        return len(self._X)

    def __getitem__(self, idx):
        image_path = self._X[idx]
        image = read_image(image_path)
        image = self.transform(image)
        
        if self._y is not None:
            label = self._y[idx]
            return image, label
        return image

# %% [markdown]
# ## Model

# %%
class Model(pl.LightningModule):
    def __init__(self, hparams):
        super().__init__()
        self.save_hyperparameters(hparams)  # 儲存超參數
        
        self.__build_model()
        
    def __build_model(self):
        if self.hparams.model.package == 'timm':
            self.backbone = create_model(self.hparams.model.name,
                                         pretrained=False, 
                                         num_classes=0, 
                                         in_chans=3)
            num_features = self.backbone.num_features
        
        elif self.hparams.model.package == 'torchvision':
            # weights = 'DEFAULT' if self.hparams.model.pretrain else None
            self.backbone = eval(self.hparams.model.name)(weights=None)
            num_features = 1000
            
        self.fc = nn.Sequential(nn.Dropout(0.5), 
                                nn.Linear(num_features, 
                                          self.hparams.model.output_dim))

    def forward(self, x):
        f = self.backbone(x)
        out = self.fc(f)
        return out

    def predict_step(self, batch, batch_idx):
        images = batch
        pred = self(images).sigmoid()  # return後會自動轉成numpy
        if pred.dim == 3:
            pred = pred.squeeze()
        return pred

# %% [markdown]
# ## Test

# %%
IMAGENET_MEAN = [0.485, 0.456, 0.406]  # RGB
IMAGENET_STD = [0.229, 0.224, 0.225]  # RGB

test_transform = T.Compose([T.Resize(config.image_size),
                            T.CenterCrop([config.image_size, config.image_size]),
                            T.ConvertImageDtype(torch.float),
                            T.Normalize(mean=IMAGENET_MEAN, std=IMAGENET_STD)])
test_transform2 = T.Compose([T.Resize(config2.image_size),
                            T.CenterCrop([config2.image_size, config2.image_size]),
                            T.ConvertImageDtype(torch.float),
                            T.Normalize(mean=IMAGENET_MEAN, std=IMAGENET_STD)])
test_transform3 = T.Compose([T.Resize(config3.image_size),
                            T.CenterCrop([config3.image_size, config3.image_size]),
                            T.ConvertImageDtype(torch.float),
                            T.Normalize(mean=IMAGENET_MEAN, std=IMAGENET_STD)])
test_transform4 = T.Compose([T.Resize(config4.image_size),
                            T.CenterCrop([config4.image_size, config4.image_size]),
                            T.ConvertImageDtype(torch.float),
                            T.Normalize(mean=IMAGENET_MEAN, std=IMAGENET_STD)])
test_transform5 = T.Compose([T.Resize(config5.image_size),
                            T.CenterCrop([config5.image_size, config5.image_size]),
                            T.ConvertImageDtype(torch.float),
                            T.Normalize(mean=IMAGENET_MEAN, std=IMAGENET_STD)])
test_transform6 = T.Compose([T.Resize(config6.image_size),
                            T.CenterCrop([config6.image_size, config6.image_size]),
                            T.ConvertImageDtype(torch.float),
                            T.Normalize(mean=IMAGENET_MEAN, std=IMAGENET_STD)])
test_transform7 = T.Compose([T.Resize(config7.image_size),
                            T.CenterCrop([config7.image_size, config7.image_size]),
                            T.ConvertImageDtype(torch.float),
                            T.Normalize(mean=IMAGENET_MEAN, std=IMAGENET_STD)])
test_transform8 = T.Compose([T.Resize(config8.image_size),
                            T.CenterCrop([config8.image_size, config8.image_size]),
                            T.ConvertImageDtype(torch.float),
                            T.Normalize(mean=IMAGENET_MEAN, std=IMAGENET_STD)])


stage = 'test'
df = pd.read_csv(os.path.join(config.root, stage+'.csv'))
df["Id"] = df["Id"].apply(lambda x: os.path.join(config.root, stage, x + ".jpg")) # 將ID改成圖片路徑
if "Pawpularity" in df.keys():
    test_y = df["Pawpularity"].astype(float).apply(lambda x: x / 100.).to_numpy() # 將Pawpularity軟換到[0, 1]
    df.drop('Pawpularity', axis=1, inplace=True)

# df to dataset
predict_data1 = PetfinderDataset(df, test_transform, config.image_size)
predict_loader1 = DataLoader(predict_data1, **config.test_loader)
predict_data2 = PetfinderDataset(df, test_transform2, config2.image_size)
predict_loader2 = DataLoader(predict_data2, **config2.test_loader)
predict_data3 = PetfinderDataset(df, test_transform3, config3.image_size)
predict_loader3 = DataLoader(predict_data3, **config3.test_loader)
predict_data4 = PetfinderDataset(df, test_transform4, config4.image_size)
predict_loader4 = DataLoader(predict_data4, **config4.test_loader)
predict_data5 = PetfinderDataset(df, test_transform5, config5.image_size)
predict_loader5 = DataLoader(predict_data5, **config5.test_loader)
predict_data6 = PetfinderDataset(df, test_transform6, config6.image_size)
predict_loader6 = DataLoader(predict_data6, **config6.test_loader)
predict_data7 = PetfinderDataset(df, test_transform7, config7.image_size)
predict_loader7 = DataLoader(predict_data7, **config7.test_loader)
predict_data8 = PetfinderDataset(df, test_transform8, config8.image_size)
predict_loader8 = DataLoader(predict_data8, **config8.test_loader)

# %% [markdown]
# ### kFold predictions

# %%
warnings.filterwarnings("ignore")  # 關閉 Warning
torch.set_float32_matmul_precision('high')  # 設置高精度(根據顯卡調整)

total_predictions1 = []
total_predictions2 = []
total_predictions3 = []
total_predictions4 = []
total_predictions5 = []
total_predictions6 = []
total_predictions7 = []
# total_predictions8 = []

for fold in range(config.n_splits):
    model_weight1 = glob(f'/kaggle/input/{config.save_dir}/fold_{fold}/version_0/*.ckpt')[0]
    model1 = Model(config).load_from_checkpoint(model_weight1, map_location='cuda:0')
    trainer1 = pl.Trainer(logger=False, precision='16-mixed')
    predictions1 = trainer1.predict(model1, dataloaders=predict_loader1)    
    total_predictions1.append(np.concatenate(predictions1).flatten())
    # 清除變數與快取
    del model1, trainer1, predictions1
    torch.cuda.empty_cache()
    gc.collect()
    
for fold in range(config2.n_splits):
    model_weight2 = glob(f'/kaggle/input/{config2.save_dir}/fold_{fold}/version_0/*.ckpt')[0]
    model2 = Model(config2).load_from_checkpoint(model_weight2, map_location='cuda:0')
    trainer2 = pl.Trainer(logger=False, precision='16-mixed')
    predictions2 = trainer2.predict(model2, dataloaders=predict_loader2)    
    total_predictions2.append(np.concatenate(predictions2).flatten())
    # 清除變數與快取
    del model2, trainer2, predictions2
    torch.cuda.empty_cache()
    gc.collect()
    
for fold in range(config3.n_splits):    
    model_weight3 = glob(f'/kaggle/input/{config3.save_dir}/fold_{fold}/version_0/*.ckpt')[0]
    model3 = Model(config3).load_from_checkpoint(model_weight3, map_location='cuda:0')
    trainer3 = pl.Trainer(logger=False, precision='16-mixed')
    predictions3 = trainer3.predict(model3, dataloaders=predict_loader3)    
    total_predictions3.append(np.concatenate(predictions3).flatten())
    # 清除變數與快取
    del model3, trainer3, predictions3
    torch.cuda.empty_cache()
    gc.collect() 
    
for fold in range(config4.n_splits):    
    model_weight4 = glob(f'/kaggle/input/{config4.save_dir}/fold_{fold}/version_0/*.ckpt')[0]
    model4 = Model(config4).load_from_checkpoint(model_weight4, map_location='cuda:0')
    trainer4 = pl.Trainer(logger=False, precision='16-mixed')
    predictions4 = trainer4.predict(model4, dataloaders=predict_loader4)    
    total_predictions4.append(np.concatenate(predictions4).flatten())
    # 清除變數與快取
    del model4, trainer4, predictions4
    torch.cuda.empty_cache()
    gc.collect() 
    
for fold in range(config5.n_splits):    
    model_weight5 = glob(f'/kaggle/input/{config5.save_dir}/fold_{fold}/version_0/*.ckpt')[0]
    model5 = Model(config5).load_from_checkpoint(model_weight5, map_location='cuda:0')
    trainer5 = pl.Trainer(logger=False, precision='16-mixed')
    predictions5 = trainer5.predict(model5, dataloaders=predict_loader5)    
    total_predictions5.append(np.concatenate(predictions5).flatten())
    # 清除變數與快取
    del model5, trainer5, predictions5
    torch.cuda.empty_cache()
    gc.collect() 

for fold in range(config6.n_splits):    
    model_weight6 = glob(f'/kaggle/input/{config6.save_dir}/fold_{fold}/version_0/*.ckpt')[0]
    model6 = Model(config6).load_from_checkpoint(model_weight6, map_location='cuda:0')
    trainer6 = pl.Trainer(logger=False, precision='16-mixed')
    predictions6 = trainer6.predict(model6, dataloaders=predict_loader6)
    total_predictions6.append(np.concatenate(predictions6).flatten())
    # 清除變數與快取
    del model6, trainer6, predictions6
    torch.cuda.empty_cache()
    gc.collect() 
                                    
for fold in range(config7.n_splits):    
    model_weight7 = glob(f'/kaggle/input/{config7.save_dir}/fold_{fold}/version_0/*.ckpt')[0]
    model7 = Model(config7).load_from_checkpoint(model_weight7, map_location='cuda:0')
    trainer7 = pl.Trainer(logger=False, precision='16-mixed')
    predictions7 = trainer7.predict(model7, dataloaders=predict_loader7)    
    total_predictions7.append(np.concatenate(predictions7).flatten())
    # 清除變數與快取
    del model7, trainer7, predictions7
    torch.cuda.empty_cache()
    gc.collect() 

# for fold in range(config8.n_splits):    
#     model_weight8 = glob(f'/kaggle/input/{config8.save_dir}/fold_{fold}/version_0/*.ckpt')[0]
#     model8 = Model(config8).load_from_checkpoint(model_weight8, map_location='cuda:0')
#     trainer8 = pl.Trainer(logger=False, precision='16-mixed')
#     predictions8 = trainer8.predict(model8, dataloaders=predict_loader8)    
#     total_predictions8.append(np.concatenate(predictions8).flatten())
#     # 清除變數與快取
#     del model8, trainer8, predictions8
#     torch.cuda.empty_cache()
#     gc.collect()

# %% [markdown]
# ### 計算平均預測分數

# %%
mean_predictions_1 = np.array(total_predictions1).mean(axis=0)
print(mean_predictions_1)
mean_predictions_2 = np.array(total_predictions2).mean(axis=0)
print(mean_predictions_2)
mean_predictions_3 = np.array(total_predictions3).mean(axis=0)
print(mean_predictions_3)
mean_predictions_4 = np.array(total_predictions4).mean(axis=0)
print(mean_predictions_4)
mean_predictions_5 = np.array(total_predictions5).mean(axis=0)
print(mean_predictions_5)
mean_predictions_6 = np.array(total_predictions6).mean(axis=0)
print(mean_predictions_6)
mean_predictions_7 = np.array(total_predictions7).mean(axis=0)
print(mean_predictions_7)
# mean_predictions_8 = np.array(total_predictions8).mean(axis=0)
# print(mean_predictions_8)

# %% [markdown]
# ### Ensemble

# %%
# mean_predictions= (1*mean_predictions_1 + 1*mean_predictions_2 + 1*mean_predictions_3 + 1*mean_predictions_4 + 1*mean_predictions_5 + 1*mean_predictions_6 + 1*mean_predictions_7)/7
mean_predictions= 0.07601696 *mean_predictions_1 + 0.17093608 *mean_predictions_2 + 0.1317575*mean_predictions_3 + 0.28074446 *mean_predictions_4 + 0.09462855 *mean_predictions_5 + 0.20099733 *mean_predictions_6 + 0.04491912*mean_predictions_7

print(mean_predictions)

# %% [markdown]
# ### 計算RMSE

# %%
# RMSE(torch.tensor(mean_predictions), torch.tensor(test_y)).item()

# %% [markdown]
# ### 儲存平均預測分數

# %%
# 儲存csv
df = pd.read_csv(os.path.join(config.root, stage+'.csv'))
df_id = df['Id']

mean_predicts_df = pd.DataFrame(mean_predictions * 100., columns=["Pawpularity"])
df = pd.concat([df_id, mean_predicts_df], axis=1)
df.to_csv("submission.csv", index=False)
df.head(8)
